# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
#Step 1:-
df = pd.read_csv(r"C:\Users\GURU\Downloads\EDA1\EDA1\Cardiotocographic.csv")
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.shape
# Out:
# (2126, 14)

# %%
df.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
# Display first few rows
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
# Check for missing values
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
# Handle missing values (if necessary) - Example: Fill with median values
df.fillna(df.median(),inplace=True)

# %%
# Check for duplicate rows
print("\n Duplicated rate:",df. duplicated().sum())
# Out:
#  Duplicated rate: 2

# %%
# Convert data types if necessary (Example: Converting object types to numeric)
df = df.apply(pd.to_numeric,errors = 'coerce')

# %%
#Step :- 2
# Statistical summary
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.340204     0.003204     0.009894     0.004391     0.001895
# std      11.214379     0.004373     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.000002     0.000173    46.995984     1.364378    10.285964
# std       0.000141     0.000836    18.813973     1.173632    21.205041
# ...

# %%
# Compute IQR for each column
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q1 - Q3
print("\n Interquantile Range (IQR):")
print(IQR)
# Out:
#  Interquantile Range (IQR):
# LB         -14.000000
# AC          -0.005606
# FM          -0.002567
# UC          -0.004685
# DL          -0.003289
# DS           0.000000
# DP           0.000000
# ASTV       -29.000000
# MSTV        -1.000000
# ALTV       -11.000000
# MLTV        -6.200000
# Width      -63.000000
# Tendency    -1.000000
# NSP          0.000000
# dtype: float64

# %%
# Standard Deviation
print("\n Standard deviation of each columns:")
print(df.std())
# Out:
#  Standard deviation of each columns:
# LB          11.214379
# AC           0.004373
# FM           0.067540
# UC           0.003340
# DL           0.003343
# DS           0.000141
# DP           0.000836
# ASTV        18.813973
# MSTV         1.173632
# ALTV        21.205041
# MLTV         7.734851
# Width       42.720508
# Tendency     0.643186
# NSP          0.642133
# dtype: float64

# %%
#Step 3:-
# Histograms for all numerical features
df.hist(figsize=(12,10), bins = 20)
plt.suptitle("Distribution of Numerical Features")
plt.show()

# %%
# Boxplots for numerical variables
plt.figure(figsize=(12,6))
sns.boxplot(data=df)
plt.xticks(rotation=45)
plt.suptitle("Boxplot for outlier Detection")
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm',fmt=".2f",linewidth=0.5 )
plt.suptitle("Correlation Heatmap")
plt.show()

# %%
# Pairplot for better visualization of relationships
sns.pairplot(df)
plt.show()
# Out:
# C:\Users\GURU\anaconda3\New folder\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# 6. Violin Plots (Example: Distribution of ASTV) 
plt.figure(figsize=(8,6))
sns.violinplot(y=df['ASTV'])
plt.title("violin plot of ASTV ", fontsize=14)
plt.show()

# %%
#Step 4:- 
# Find the most correlated features
correlation_matrics = df.corr()
high_corr_feature = correlation_matrics[abs(correlation_matrics) > 0.5]
print("\nHighly Correlated Features:")
print(correlation_matrics)
# Out:
# Highly Correlated Features:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.062813  0.018807 -0.166229 -0.126563 -0.005432
# AC       -0.062813  1.000000  0.009768  0.071621 -0.093449 -0.033088
# FM        0.018807  0.009768  1.000000 -0.053226  0.009718  0.029916
# UC       -0.166229  0.071621 -0.053226  1.000000  0.190128 -0.006938
# DL       -0.126563 -0.093449  0.009718  0.190128  1.000000  0.058413
# DS       -0.005432 -0.033088  0.029916 -0.006938  0.058413  1.000000
# DP       -0.047650 -0.083298  0.121459  0.070295  0.144717  0.004321
# ASTV      0.241857 -0.230470 -0.032691 -0.181161 -0.069361  0.008426
# MSTV     -0.169647  0.132962  0.017055  0.189406  0.410102  0.016026
# ALTV      0.210542 -0.269807 -0.011936 -0.227304 -0.186967 -0.004335
# MLTV     -0.003423 -0.104853 -0.006121 -0.049452 -0.165293  0.034367
# Width    -0.118397  0.234549  0.097282  0.107083  0.408578  0.040845
# ...

# %%
#Step 5:- 
# Summary of Findings
print("\nKey Insights:")
print("- The dataset contains {} rows and {} columns.".format(df.shape[0], df.shape[1]))
print("- No missing values after handling them.")
print("- Features with high correlation might indicate significant relationships.")
print("- Outliers were identified in some features.")
print("- Correlation heatmap helped in identifying variable dependencies.")
# Out:
# Key Insights:
# - The dataset contains 2126 rows and 14 columns.
# - No missing values after handling them.
# - Features with high correlation might indicate significant relationships.
# - Outliers were identified in some features.
# - Correlation heatmap helped in identifying variable dependencies.

# %%
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()
